# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import posixpath as px
from info_vis import preprocessing, PROJECT_PATH, DATA_PATH, OUTPUT_DATA_PATH

# %% [markdown]
# ## Load Data

# %%
filename = "GDP.csv"
gdp_df = pd.read_csv(px.join(DATA_PATH, filename))
gdp_df
# Out:
#       Country/Area  Year Unit GDP, at current prices - US Dollars
# 0      Afghanistan  1970  US$                   1748886596.862996
# 1      Afghanistan  1971  US$                   1831108981.957219
# 2      Afghanistan  1972  US$                  1595555481.8054674
# 3      Afghanistan  1973  US$                  1733333275.4378521
# 4      Afghanistan  1974  US$                  2155555500.3670335
# ...            ...   ...  ...                                 ...
# 13495     Zimbabwe  2019  US$                         22594520375
# 13496     Zimbabwe  2020  US$                         21664745864
# 13497     Zimbabwe  2021  US$                         24118150864
# 13498     Zimbabwe  2022  US$                         26418592961
# 13499     Zimbabwe  2023  US$                         30368203559
#
# [13500 rows x 4 columns]

# %%
filename = "World_Wide_Unicorn_Startups.csv"
unicorn_startups_df = pd.read_csv(px.join(DATA_PATH, filename))
unicorn_startups_df
# Out:
#              Company  Valuation        Date        Country           City  \
# 0          Bytedance      140.0    4/7/2017          China        Beijing
# 1             SpaceX      100.3   12/1/2012  United States      Hawthorne
# 2             Stripe       95.0   1/23/2014  United States  San Francisco
# 3             Klarna       45.6  12/12/2011         Sweden      Stockholm
# 4              Canva       40.0    1/8/2018      Australia    Surry Hills
# ..               ...        ...         ...            ...            ...
# 931        YipitData        1.0   12/6/2021  United States       New York
# 932         Anyscale        1.0   12/7/2021  United States       Berkeley
# 933  Iodine Software        1.0   12/1/2021  United States         Austin
# 934       ReliaQuest        1.0   12/1/2021  United States          Tampa
# 935       Pet Circle        1.0   12/7/2021      Australia     Alexandria
#
#                             Industry  \
# 0            Artificial intelligence
# 1                              Other
# 2                            Fintech
# 3                            Fintech
# 4       Internet software & services
# ..                               ...
# 931     Internet software & services
# 932          Artificial Intelligence
# 933      Data management & analytics
# 934                    Cybersecurity
# 935  E-commerce & direct-to-consumer
#
#                                              Investors  year  month  day
# 0    0      Sequoia Capital China, SIG Asia Investm...  2017      7    4
# 1    0      Sequoia Capital China, SIG Asia Investm...  2012      1   12
# 2    0      Sequoia Capital China, SIG Asia Investm...  2014     23    1
# 3    0      Sequoia Capital China, SIG Asia Investm...  2011     12   12
# 4    0      Sequoia Capital China, SIG Asia Investm...  2018      8    1
# ..                                                 ...   ...    ...  ...
# 931  0      Sequoia Capital China, SIG Asia Investm...  2021      6   12
# 932  0      Sequoia Capital China, SIG Asia Investm...  2021      7   12
# 933  0      Sequoia Capital China, SIG Asia Investm...  2021      1   12
# 934  0      Sequoia Capital China, SIG Asia Investm...  2021      1   12
# 935  0      Sequoia Capital China, SIG Asia Investm...  2021      7   12
#
# [936 rows x 10 columns]

# %%
filename = "Quality_of_Life.csv"
quality_life_df = pd.read_csv(px.join(DATA_PATH, filename))
quality_life_df
# Out:
#                country  Purchasing Power Value Purchasing Power Category  \
# 0          Afghanistan                   32.15                'Very Low'
# 1        Aland Islands                  125.01               'Very High'
# 2              Albania                   42.82                     'Low'
# 3             Alderney                    0.00                       NaN
# 4              Algeria                   27.60                'Very Low'
# ..                 ...                     ...                       ...
# 231  Wallis And Futuna                    0.00                       NaN
# 232     Western Sahara                    0.00                       NaN
# 233              Yemen                   20.74                'Very Low'
# 234             Zambia                   22.32                'Very Low'
# 235           Zimbabwe                   28.76                'Very Low'
#
#      Safety Value Safety Category  Health Care Value Health Care Category  \
# 0           25.33           'Low'              24.24                'Low'
# 1           71.81          'High'              79.72               'High'
# 2           55.52      'Moderate'              48.21           'Moderate'
# 3           83.79     'Very High'             100.00          'Very High'
# 4           47.54      'Moderate'              54.43           'Moderate'
# ..            ...             ...                ...                  ...
# 231          0.00             NaN               0.00                  NaN
# 232         62.87          'High'               0.00                  NaN
# 233         34.07           'Low'              25.31                'Low'
# 234         54.39      'Moderate'              54.44           'Moderate'
# 235         39.31           'Low'              44.80           'Moderate'
#
#      Climate Value Climate Category  Cost of Living Value  \
# 0             0.00              NaN                 21.08
# 1             0.00              NaN                 53.44
# 2            86.43      'Very High'                 40.85
# 3             0.00              NaN                  0.00
# 4            94.82      'Very High'                 25.31
# ..             ...              ...                   ...
# 231           0.00              NaN                  0.00
# 232           0.00              NaN                  0.00
# 233           0.00              NaN                 48.66
# 234           0.00              NaN                 36.74
# 235          96.76      'Very High'                 35.36
#
#     Cost of Living Category Property Price to Income Value  \
# 0                'Very Low'                            7.8
# 1                     'Low'                           5.33
# 2                     'Low'                          14.88
# 3                       NaN                            0.0
# 4                'Very Low'                           21.7
# ..                      ...                            ...
# 231                     NaN                            0.0
# 232                     NaN                          12.75
# 233                   'Low'                          15.98
# 234              'Very Low'                          72.42
# 235              'Very Low'                          17.35
#
#     Property Price to Income Category  Traffic Commute Time Value  \
# 0                               'Low'                       56.17
# 1                               'Low'                       19.05
# 2                              'High'                       36.74
# 3                                 NaN                        5.00
# 4                         'Very High'                       45.09
# ..                                ...                         ...
# 231                               NaN                        0.00
# 232                            'High'                        0.00
# 233                            'High'                       15.00
# 234                       'Very High'                       38.86
# 235                       'Very High'                       27.79
#
#     Traffic Commute Time Category  Pollution Value Pollution Category  \
# 0                     'Very High'            84.44        'Very High'
# 1                      'Very Low'            18.05         'Very Low'
# 2                      'Moderate'            77.25             'High'
# 3                      'Very Low'             1.72         'Very Low'
# 4                          'High'            63.87             'High'
# ..                            ...              ...                ...
# 231                           NaN             0.00                NaN
# 232                           NaN             0.00                NaN
# 233                    'Very Low'            83.17        'Very High'
# 234                    'Moderate'            80.90        'Very High'
# 235                         'Low'            78.53             'High'
#
#     Quality of Life Value Quality of Life Category
# 0                     0.0                      NaN
# 1                     0.0                      NaN
# 2              ': 104.16'                    'Low'
# 3                     0.0                      NaN
# 4               ': 98.83'               'Very Low'
# ..                    ...                      ...
# 231                   0.0                      NaN
# 232                   0.0                      NaN
# 233                   0.0                      NaN
# 234                   0.0                      NaN
# 235             ': 94.20'               'Very Low'
#
# [236 rows x 19 columns]

# %% [markdown]
# ## Preprocess Data

# %%
# TODO:

# %% [markdown]
# ## Merge data

# %%
# TODO:

# %%
filename = "preprocessed_data.csv"
preprocessed_data.to_csv(px.join(OUTPUT_DATA_PATH, filename), index=False)

# %%
test_df = pd.read_csv(px.join(OUTPUT_DATA_PATH, filename))
test_df
